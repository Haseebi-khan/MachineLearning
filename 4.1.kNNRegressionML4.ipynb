# %% [markdown]
# # **k-NN Regression**

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsRegressor

# %%
X = np.array([[10], [20], [30], [40], [50], [60], [70], [80], [90]])
y = np.array([3, 16, 15, 47, 58, 79, 80, 98, 64])

# %%
plt.scatter(X, y, color="red", label="Traning Data.")
plt.xlabel("Features")
plt.ylabel("Target")
plt.title("kNN Regression")
plt.grid(True)
plt.legend()
plt.show()

# %%
knn = KNeighborsRegressor(n_neighbors=3)
knn.fit(X, y)
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %%
new_point = np.array([[45],[23],[55],[21],[80], [43],[78],[100],[85]])
prediction =knn.predict(new_point)
prediction
# Out:
# array([40.        , 11.33333333, 61.33333333, 11.33333333, 80.66666667,
#        40.        , 80.66666667, 80.66666667, 80.66666667])

# %%
plt.scatter(X, y , color="black", label="Training data")
plt.scatter(new_point, prediction, color="green", label="prediction")
plt.xlabel("Features")
plt.ylabel("Targets")
plt.title("kNN regression")
plt.grid(True)
plt.legend()
plt.show()

# %%
print(f"Predicted value at x = 45:   {prediction[0]}")
# Out:
# Predicted value at x = 45:   40.0
