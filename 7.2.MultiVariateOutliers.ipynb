# %% [markdown]
# ## **Multi Variate Analysis to Handle Outliers:**

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

df = pd.read_csv(r"D:\Codes\MachineLearning\Datasets\AmesHousing.csv")
df
